# %% [markdown]
# # Welcome to Python - Beginner Level
#
# This notebook covers fundamental Python concepts for beginners.
#
# ## Topics Covered
# - Variables and Data Types
# - Basic Operations
# - Print Statements
# - Simple Input/Output

# %%
# Your first Python code!
print("Hello, World!")
